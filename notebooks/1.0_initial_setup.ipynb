# %%
import pandas as pd
import numpy as np
import os
from pathlib import Path

# Define project root directory (assuming notebook is in notebooks/ folder)
PROJ_ROOT = Path(os.getcwd()).parent
DATA_RAW = PROJ_ROOT / 'data' / 'raw'
DATA_PROCESSED = PROJ_ROOT / 'data' / 'processed'

print(f"Project Root: {PROJ_ROOT}")
print(f"Raw Data Dir: {DATA_RAW}")
print(f"Exists? {DATA_RAW.exists()}")
